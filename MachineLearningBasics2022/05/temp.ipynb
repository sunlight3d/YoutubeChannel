# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import math
import pickle #dump or save your model
from joblib import dump,load

# %%
# load the dataset as a pandas DataFrame
# premeno(dưới 51 tuổi) => khởi đầu của sự suy giảm estrogen dẫn đến thời kỳ mãn kinh
# Tumor size: the greatest diameter (in mm)
filename = 'breast-cancer.csv'
dataframe = pd.read_csv(filename)
dataframe
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    40-49   premeno      15-19       0-2       yes          3  right
# 1    50-59      ge40      15-19       0-2        no          1  right
# 2    50-59      ge40      35-39       0-2        no          2   left
# 3    40-49   premeno      35-39       0-2       yes          3  right
# 4    40-49   premeno      30-34       3-5       yes          2   left
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  50-59      ge40      30-34       6-8       yes          2   left
# 282  50-59   premeno      25-29       3-5       yes          2   left
# 283  30-39   premeno      30-34       6-8       yes          2  right
# 284  50-59   premeno      15-19       0-2        no          2  right
# 285  50-59      ge40      40-44       0-2        no          3   left
#
#     breast-quad irradiat                 Class
# 0       left_up       no     recurrence-events
# ...

# %%
#dataframe['age'].drop_duplicates().sort_values()
tumor_sizes = []
dictionary = {}
i = 1
for index, value in dataframe['tumor-size'].drop_duplicates().items():
    print(f"Index : {index}, Value : {value}")        
    tumor_sizes.append(value)
    dictionary[value] = i
    i = i + 1    
tumor_sizes.sort(key=lambda item: int(item.split('-')[0]))
dictionary
dataframe['breast-quad'].drop_duplicates()
dataframe['breast'].drop_duplicates()
# Out:
# Index : 0, Value : 15-19
# Index : 2, Value : 35-39
# Index : 4, Value : 30-34
# Index : 5, Value : 25-29
# Index : 6, Value : 40-44
# Index : 7, Value : 10-14
# Index : 8, Value : 0-4
# Index : 15, Value : 20-24
# Index : 37, Value : 45-49
# Index : 48, Value : 50-54
# Index : 114, Value : 5-9
# 0    right
# 2     left
# Name: breast, dtype: object

# %%
dataframe['age'].drop_duplicates().sort_values()
dataframe["age"] = dataframe["age"].map({
    '20-29': 1,
    '30-39': 2,
    '40-49':3,
    '50-59': 4,
    '60-69': 5,
    '70-79': 6    
})
dataframe["age"]
# Out:
# 0      3
# 1      4
# 2      4
# 3      3
# 4      3
#       ..
# 281    4
# 282    4
# 283    2
# 284    4
# 285    4
# Name: age, Length: 286, dtype: int64
